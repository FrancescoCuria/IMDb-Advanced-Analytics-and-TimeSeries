# %% [markdown]
# #### `originalTitle`:
# original title, in the original language
#
# - normalized string: removed uppercase, special chars,...
#
# #### `startYear`: DROPPED
# represents the release year of a title. In the case of TV Series, it is the series start year.
#
# - created `startYearDecade` to have less variance
#
# #### `endYear`: DROPPED
# TV Series end year.
#
# #### `worstRating`: DROPPED
# worst title rating.
#
# #### `bestRating`: DROPPED
# best title rating.
#
# #### `isRatable`: DROPPED
# wether or not the title can be rated by users.
#
# #### `totalImages` and `totalVideos`: BOTH DROPPED
# Total Number of Images and videos for the title within the IMDb title page.
#
# - merged in a new feature `totalMedia = totalImages + totalVideos`
#
# #### `awardWins` and `awardNominationsExcludeWins`: BOTH DROPPED
# Number of awards the title won and of award nominations excluding wins.
#
# - merged in a new feature `totalRecognitions = awardWins+awardNominationsExcludeWins`
#
# #### `rating` (DROPPED) and `averageRating`
# IMDB title rating class and weighted average of all the individual user ratings.
#
# #### `titleType` TODO - LABEL-ENCODING
# The type/format of the title (e.g. movie, short, tvseries, tvepisode, video, etc).
#
# - old titleTypes: short, movie, tvSeries, tvEpisode, tvMovie, tvMiniSeries, tvShort, tvSpecial, viedo, videoGame
#
# - merged `tvShort` in `short`
# - merged `tvMiniSeries` in `tvSeries`
# - merged `tvSpecial` in `tvEpisode`
# - merged `tvMovie` and `movi
# - numVotes: 			Number of votes the title has received.
# - totalCredits:			Total Number of Credits for the title.
# - criticReviewsTotal:		Total Number of Critic Reviews.
# - userReviewsTotal  		Total Number of Users Reviews.
# - castNumber: 			Total Number of Cast individuals present within the IMDb title page.
# - CompaniesNumber: 		Total Number of companies that worked for the title.
#
# - quotesTotal:			Total Number of quotes the title has within the IMDb page.
# - writerCredits:		Total number of writer credits of the title.
# - directorCredits: 		Total number of director credits of the title.
# e`
# - dropped `videoGame`
#
# - new titleTypes: short, tvSeries, tvEpisode, movie, video
#
# #### `genres` TODO: ONE-HOT-ENCODING e MISSING VALUES
# The genre(s) associated with the title (e.g., drama, comedy, action).
#
# - manipulated in order to have a list of string
# - dropped missing genres rows
#
# #### `soundMixes` DROPPED
# Technical specification of the sound mixes available for the title.
#
# - dropped
#
# #### `regions` and `numRegions` (DROPPED) TODO - CHECK AFTER ONE HOT ENCODING CORRELATION
# The regions for this version of the title and the regions number for this version of the title, respectively
#
# - CREATE IN ONE HOT ENCODING THECOLUMN "num_regions" per confrontarla e valutare la correlazione con numRegions
#
# #### `countryOfOrigin` TODO - ONE-HOT-ENCODING
# The country where the title was primarily produced.
#
# #### `runtimeMinutes` (dropped and created runtimeHours to reduce variance)
# Primary runtime of the title, in minutes.
#
# - dropped `runtimeMinutes`
# - created `runtimeHours`
#
# Imputed values using GaussianMixture (in 01_data_overview.ipynb)
#
# #### `isAdult` TODO - controllare col genera `adult` come sono messe le ose e adottare la strategia più conservativa e droppare una colonna
# Whether or not the title is for adult. 0: non-adult title; 1: adult title.
#
# #### `canHaveEpisodes` (DROPPED, the information is inside `titleType`)
# Whether or not the title can have episodes.
#
#
# #### `ratingCount`: DROPPED (high correlation)
# - The total number of user ratings submitted for the title.
#
# #### `externalLinks`: DROPPED (high correlation)
# - Total Number of External Links the title has within the IMDb page.
#
#
# - numVotes: 			Number of votes the title has received.
# - totalCredits:			Total Number of Credits for the title.
# - criticReviewsTotal:		Total Number of Critic Reviews.
# - userReviewsTotal  		Total Number of Users Reviews.
# - castNumber: 			Total Number of Cast individuals present within the IMDb title page.
# - CompaniesNumber: 		Total Number of companies that worked for the title.
#
# - quotesTotal:			Total Number of quotes the title has within the IMDb page.
# - writerCredits:		Total number of writer credits of the title.
# - directorCredits: 		Total number of director credits of the title.
